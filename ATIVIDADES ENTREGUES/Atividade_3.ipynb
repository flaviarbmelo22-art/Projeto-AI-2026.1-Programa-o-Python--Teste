# %% [markdown]
# CETAM - Centro de Educação Tecnólogica do Amazonas
#
# Curso Técnico em Nível Médio de Inteligência Artificial
#
# Manaus, 23 de março de 2026
#
# Aluno: Flávia Melo / Halana Ribeiro

# %%
print('olá, mundo')
# Out:
# olá, mundo

# %%
2 + 3
# Out:
# 5

# %%
50 - 5 * 7
# Out:
# 15

# %%
(50 - 5*6)/2
# Out:
# 10.0

# %%
print (int(8/5))   # divisão com operandos inteiros, retorna resultado inteiro(vs.2.7)
print (8./5)       # divisão com pelo menos um operador real, retorna resultado real (vs.2.7)
# Out:
# 1
# 1.6

# %%
5**2              # 5 elevado ao quadrado
# Out:
# 25

# %%
59**-2
# Out:
# 0.0002872737719046251

# %%
numero= 59
Resultado= bin (numero)
print (Resultado) # saida
# Out:
# 0b111011

# %%
def calculadora():
    print('---Mini Calculadora---')
    print('\nSelecione a operacao:')
    print('1 - Adicao (+)')
    print('2 - Subtracao (-)')
    print('3 - Multiplicacao (*)')
    print('4 - Divisao (/)')

# %%
calculadora()
# Out:
# ---Mini Calculadora---
#
# Selecione a operacao:
# 1 - Adicao (+)
# 2 - Subtracao (-)
# 3 - Multiplicacao (*)
# 4 - Divisao (/)
